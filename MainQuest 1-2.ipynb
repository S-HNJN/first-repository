# %%
import random as rd
import time

class Character:
    def __init__(self, name):
        self.name = name
        self.level = 1
        self.health = 100
        self.attack_power = 25
        self.defence_power = 5

    def is_alive(self):
        if self.health > 0:
            return True
        else:
            return False

    
    def take_damage(self, recieved_damage):
        if self.defence_power >= recieved_damage:
            return False
        else:
            self.health -= (recieved_damage-self.defence_power)
            return True

    def attack_target(self):
        damage = rd.randint(1,self.attack_power)
        return damage

class Player(Character):
    def __init__(self,name):
        super().__init__(name)
        self.experience = 0
        self.wallet = 0
        self.inventory = []

    def gain_experience(self, exp):
        self.experience += exp
        if self.experience >= 50:
            self.level += 1
            self.attack_power += 10
            self.defence_power += 5
            print('Level Up!')

    def gain_money(self, money):
        self.wallet += money

class Monster(Character):
    def __init__(self, name, level):
        self.name = name
        self.level = level
        self.health = rd.randint(10,30)*self.level
        self.attack_power = rd.randint(5,20)*self.level
        self.defence_power = rd.randint(1,5)*self.level
        self.money = rd.randint(100,500)*self.level

def battle(player, monster):# 때린 인스턴스가 확률적으로 계속 때릴 수 있게 할지, 선공만 정해진 채로 순서대로 공격할지 정해야함.
    print(f'\n{monster.name} 과의 전투를 시작합니다.')
    while True:
        time.sleep(3)
        n = rd.random()
        if n < 0.5:# player 공격
            print(f'\n"{player.name}의 공격"')
            result = monster.take_damage(player.attack_target())
            if result:
                print(f'{player.name} 이/가 {monster.name}에게 {player.attack_target()} 만큼 공격했다...!')
                print(f'{monster.name} 의 체력: {monster.health}')
            else:
                print(f'{monster.name} 이/가 방어 성공')
            if monster.is_alive() is True:
                continue
            else:
                player.gain_experience(monster.level*20)
                player.gain_money(monster.money)
                print(f'전투 승리!\n현재 가진 돈 : {player.wallet}')
                break
        else:# monster 공격
            print(f'\n"{monster.name}의 공격"')
            result = player.take_damage(monster.attack_target())
            if result:
                print(f'{monster.name} 이/가 {player.name}에게 {monster.attack_target()} 만큼 공격했다...!')
                print(f'{player.name} 의 체력: {player.health}')
            else:
                print(f'{player.name} 이/가 방어 성공')
            if player.is_alive() is True:
                continue
            else:
                print('전투 패배..')
                break

class Store:
    def __init__(self):
        self.menu=[{'name':'빨간_포션','가격':500,'회복량':rd.randint(8,12)},
                  {'name':'주황_포션','가격':700,'회복량':rd.randint(12,16)},
                  {'name':'하얀_포션','가격':1000,'회복량':rd.randint(16,20)}]

    def print_menu(self, player):
        self.__init__()
        print('='*30)
        for i, item in enumerate(self.menu):
            print(f'{i+1}. {item['name']} 가격 : {item['가격']}, 회복량 : {item['회복량']}')
        print('='*30)
        while True:
            n = int(input('구매를 원하는 번호를 선택해주세요(나가시고 싶으면 다른 숫자를 입력하세요.): '))
            if 0 < n <= len(self.menu):
                self.buy(player, n)
            else:
                m = input('정말 상점을 나가시겠습니까?(y/n): ')
                if m in ('y','Y','yes','YES','Yes'):
                    break
                else:
                    continue
        
    def buy(self, player, n):
        if player.wallet >= self.menu[n-1]['가격']:
            print('포션을 구매합니다.')
            player.inventory.append(self.menu[n-1])
            player.wallet -= self.menu[n-1]['가격']
        else:
            print('돈이 부족합니다.')

monster_dict = {'슬라임': 1, '고블린': 2, '오크': 3}
def main():
    name = input('원하시는 이름을 입력해주세요: ')
    store = Store()
    player = Player(name)
    for k,v in monster_dict.items():
        monster = Monster(k,v)
        battle(player,monster)
        if player.is_alive():
            print(f'{monster.name}을 이겼다!')
            n = input('\n상점을 다녀오시겠습니까?(y/n): ')
            if n in ('y','Y','yes','YES','Yes'):
                store.print_menu(player)
            time.sleep(3)
            continue
        else:
            print('GAME OVER')
            break

# %%
main()
# Out:
# 원하시는 이름을 입력해주세요:  히어로
# 슬라임 과의 전투를 시작합니다.
#
# "슬라임의 공격"
# 슬라임 이/가 히어로에게 13 만큼 공격했다...!
# 히어로 의 체력: 96
#
# "히어로의 공격"
# 히어로 이/가 슬라임에게 14 만큼 공격했다...!
# 슬라임 의 체력: 26
#
# "슬라임의 공격"
# 슬라임 이/가 히어로에게 7 만큼 공격했다...!
# 히어로 의 체력: 92
#
# "히어로의 공격"
# 슬라임 이/가 방어 성공
#
# "슬라임의 공격"
# 슬라임 이/가 히어로에게 2 만큼 공격했다...!
# 히어로 의 체력: 86
#
# "슬라임의 공격"
# 슬라임 이/가 히어로에게 11 만큼 공격했다...!
# 히어로 의 체력: 84
#
# "히어로의 공격"
# 슬라임 이/가 방어 성공
#
# "슬라임의 공격"
# 슬라임 이/가 히어로에게 13 만큼 공격했다...!
# 히어로 의 체력: 81
#
# "슬라임의 공격"
# 슬라임 이/가 히어로에게 9 만큼 공격했다...!
# 히어로 의 체력: 79
#
# "히어로의 공격"
# 슬라임 이/가 방어 성공
#
# "히어로의 공격"
# 히어로 이/가 슬라임에게 21 만큼 공격했다...!
# 슬라임 의 체력: 17
#
# "히어로의 공격"
# 히어로 이/가 슬라임에게 21 만큼 공격했다...!
# 슬라임 의 체력: -4
# 전투 승리!
# 현재 가진 돈 : 211
# 슬라임을 이겼다!
# 상점을 다녀오시겠습니까?(y/n):  y
# 1. 빨간_포션 가격 : 500, 회복량 : 9
# 2. 주황_포션 가격 : 700, 회복량 : 14
# 3. 하얀_포션 가격 : 1000, 회복량 : 19
# 구매를 원하는 번호를 선택해주세요(나가시고 싶으면 다른 숫자를 입력하세요.):  1
# 돈이 부족합니다.
# 구매를 원하는 번호를 선택해주세요(나가시고 싶으면 다른 숫자를 입력하세요.):  12
# 정말 상점을 나가시겠습니까?(y/n):  y
# 고블린 과의 전투를 시작합니다.
#
# "고블린의 공격"
# 고블린 이/가 히어로에게 7 만큼 공격했다...!
# 히어로 의 체력: 58
#
# "히어로의 공격"
# 히어로 이/가 고블린에게 4 만큼 공격했다...!
# 고블린 의 체력: 43
#
# "고블린의 공격"
# 고블린 이/가 히어로에게 19 만큼 공격했다...!
# 히어로 의 체력: 50
#
# "히어로의 공격"
# 고블린 이/가 방어 성공
#
# "히어로의 공격"
# 히어로 이/가 고블린에게 13 만큼 공격했다...!
# 고블린 의 체력: 33
#
# "고블린의 공격"
# 고블린 이/가 히어로에게 7 만큼 공격했다...!
# 히어로 의 체력: 46
#
# "히어로의 공격"
# 히어로 이/가 고블린에게 11 만큼 공격했다...!
# 고블린 의 체력: 29
